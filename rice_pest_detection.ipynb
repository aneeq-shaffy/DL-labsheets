# %% [markdown]
# <a href="https://colab.research.google.com/github/aneeq-shaffy/DL-labsheets/blob/main/rice_pest_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Rice Pest Detection - Complete Training Pipeline
EfficientNetB0 Transfer Learning | TFLite Export | Google Colab Ready
"""

# ============================================================
# 1. IMPORTS & SETUP
# ============================================================
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks, mixed_precision
from tensorflow.keras.applications import EfficientNetB0
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns

# Enable mixed precision
policy = mixed_precision.Policy('mixed_float16')
mixed_precision.set_global_policy(policy)
print(f"Mixed precision policy: {policy.name}")

# Reproducibility
tf.random.set_seed(42)
np.random.seed(42)

# ============================================================
# 2. DATASET DOWNLOAD & PATH SETUP
# ============================================================
import kagglehub
dataset_path = kagglehub.dataset_download("mathumithram/rice-pest-detection")
print(f"Dataset downloaded to: {dataset_path}")

# Walk the directory to find the folder containing class subdirectories
data_dir = dataset_path
for root, dirs, files in os.walk(dataset_path):
    # Look for a directory that has subdirectories (class folders) with images
    if dirs and any(
        any(f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.webp'))
            for f in os.listdir(os.path.join(root, d)))
        for d in dirs if os.path.isdir(os.path.join(root, d))
    ):
        data_dir = root
        break

print(f"Using data directory: {data_dir}")

# Map numeric folder names to actual pest names
PEST_LABELS = {
    '0': 'Rice Leaf Roller',
    '1': 'Rice Leaf Caterpillar',
    '2': 'Paddy Stem Maggot',
    '3': 'Asiatic Rice Borer',
    '4': 'Yellow Rice Borer',
    '5': 'Rice Gall Midge',
    '6': 'Brown Plant Hopper',
    '7': 'Rice Stem Fly',
    '8': 'Rice Water Weevil',
    '9': 'Rice Leaf Hopper',
    '10': 'Rice Shell Pest',
    '11': 'Thrips',
}

folder_names = sorted([
    d for d in os.listdir(data_dir)
    if os.path.isdir(os.path.join(data_dir, d)) and not d.startswith('.')
])
class_names = [PEST_LABELS.get(f, f) for f in folder_names]
print(f"Classes found ({len(class_names)}): {class_names}")

for f, c in zip(folder_names, class_names):
    count = len(os.listdir(os.path.join(data_dir, f)))
    print(f"  {f} ({c}): {count} images")

# ============================================================
# 3. DATA LOADING WITH TRAIN/VAL SPLIT
# ============================================================
IMG_SIZE = 224
BATCH_SIZE = 32

train_ds = keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=42,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode="categorical",
)

val_ds = keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=42,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode="categorical",
)

NUM_CLASSES = len(class_names)
print(f"\nNum classes: {NUM_CLASSES}")

# ============================================================
# 4. COMPUTE CLASS WEIGHTS
# ============================================================
all_labels = []
for _, labels in train_ds.unbatch():
    all_labels.append(np.argmax(labels.numpy()))
all_labels = np.array(all_labels)

label_counts = Counter(all_labels)
print(f"\nTrain label distribution: {dict(sorted(label_counts.items()))}")

class_weights_array = compute_class_weight(
    class_weight='balanced',
    classes=np.arange(NUM_CLASSES),
    y=all_labels,
)
class_weight_dict = {i: w for i, w in enumerate(class_weights_array)}
print(f"Class weights: {class_weight_dict}")

# ============================================================
# 5. DATA AUGMENTATION & PREFETCHING
# ============================================================
AUTOTUNE = tf.data.AUTOTUNE

data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.3),
    layers.RandomZoom((-0.2, 0.2)),
    layers.RandomContrast(0.2),
    layers.RandomTranslation(0.1, 0.1),
], name="data_augmentation")

train_ds = train_ds.prefetch(AUTOTUNE)
val_ds = val_ds.prefetch(AUTOTUNE)

# ============================================================
# 6. BUILD MODEL
# ============================================================
base_model = EfficientNetB0(
    include_top=False,
    weights="imagenet",
    input_shape=(IMG_SIZE, IMG_SIZE, 3),
)
base_model.trainable = False

inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = data_augmentation(inputs)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.4)(x)
x = layers.Dense(256, activation="relu")(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.3)(x)
# Float32 output for numerical stability with mixed precision
outputs = layers.Dense(NUM_CLASSES, activation="softmax", dtype="float32")(x)

model = keras.Model(inputs, outputs)
model.summary()

# ============================================================
# 7. PHASE 1 — TRAIN HEAD ONLY
# ============================================================
SAVE_DIR = "saved_models"
os.makedirs(SAVE_DIR, exist_ok=True)

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

phase1_callbacks = [
    callbacks.EarlyStopping(
        monitor="val_accuracy", patience=5, restore_best_weights=True, mode="max"
    ),
    callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=3, min_lr=1e-6, verbose=1
    ),
    callbacks.ModelCheckpoint(
        os.path.join(SAVE_DIR, "best_model_phase1.h5"),
        monitor="val_accuracy", save_best_only=True, mode="max", verbose=1,
    ),
]

print("\n" + "=" * 60)
print("PHASE 1: Training head layers (base frozen)")
print("=" * 60)

history1 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=phase1_callbacks,
    class_weight=class_weight_dict,
)

# ============================================================
# 8. PHASE 2 — FINE-TUNE TOP LAYERS OF BASE
# ============================================================
base_model.trainable = True

# Freeze all layers except the last 30
for layer in base_model.layers[:-30]:
    layer.trainable = False

trainable_count = sum(1 for l in model.layers if l.trainable)
total_params = model.count_params()
trainable_params = sum(
    tf.reduce_prod(v.shape).numpy() for v in model.trainable_variables
)
print(f"\nTrainable params after unfreezing: {trainable_params:,} / {total_params:,}")

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

phase2_callbacks = [
    callbacks.EarlyStopping(
        monitor="val_accuracy", patience=7, restore_best_weights=True, mode="max"
    ),
    callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=3, min_lr=1e-7, verbose=1
    ),
    callbacks.ModelCheckpoint(
        os.path.join(SAVE_DIR, "best_model_final.h5"),
        monitor="val_accuracy", save_best_only=True, mode="max", verbose=1,
    ),
]

print("\n" + "=" * 60)
print("PHASE 2: Fine-tuning top layers of EfficientNetB0")
print("=" * 60)

history2 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=30,
    callbacks=phase2_callbacks,
    class_weight=class_weight_dict,
)

# ============================================================
# 9. EVALUATION
# ============================================================
print("\n" + "=" * 60)
print("EVALUATION")
print("=" * 60)

val_loss, val_acc = model.evaluate(val_ds)
print(f"\nFinal Validation Loss: {val_loss:.4f}")
print(f"Final Validation Accuracy: {val_acc:.4f}")

# Predictions
y_true, y_pred = [], []
for images, labels in val_ds:
    preds = model.predict(images, verbose=0)
    y_true.extend(np.argmax(labels.numpy(), axis=1))
    y_pred.extend(np.argmax(preds, axis=1))

y_true = np.array(y_true)
y_pred = np.array(y_pred)

# Classification report
print("\n--- Classification Report ---")
print(classification_report(y_true, y_pred, target_names=class_names, digits=4))

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(max(10, NUM_CLASSES), max(8, NUM_CLASSES * 0.8)))
sns.heatmap(
    cm, annot=True, fmt="d", cmap="Blues",
    xticklabels=class_names, yticklabels=class_names,
)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.savefig(os.path.join(SAVE_DIR, "confusion_matrix.png"), dpi=150)
plt.show()

# ============================================================
# 10. TRAINING HISTORY PLOTS
# ============================================================
def plot_history(h1, h2):
    acc = h1.history["accuracy"] + h2.history["accuracy"]
    val_acc = h1.history["val_accuracy"] + h2.history["val_accuracy"]
    loss = h1.history["loss"] + h2.history["loss"]
    val_loss = h1.history["val_loss"] + h2.history["val_loss"]
    epochs = range(1, len(acc) + 1)
    phase1_end = len(h1.history["accuracy"])

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

    ax1.plot(epochs, acc, label="Train Accuracy")
    ax1.plot(epochs, val_acc, label="Val Accuracy")
    ax1.axvline(x=phase1_end, color="gray", linestyle="--", label="Fine-tune start")
    ax1.set_title("Accuracy")
    ax1.set_xlabel("Epoch")
    ax1.legend()
    ax1.grid(True, alpha=0.3)

    ax2.plot(epochs, loss, label="Train Loss")
    ax2.plot(epochs, val_loss, label="Val Loss")
    ax2.axvline(x=phase1_end, color="gray", linestyle="--", label="Fine-tune start")
    ax2.set_title("Loss")
    ax2.set_xlabel("Epoch")
    ax2.legend()
    ax2.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig(os.path.join(SAVE_DIR, "training_history.png"), dpi=150)
    plt.show()

plot_history(history1, history2)

# ============================================================
# 11. SAVE FINAL MODEL (.h5)
# ============================================================
final_h5_path = os.path.join(SAVE_DIR, "rice_pest_model_final.h5")
model.save(final_h5_path)
print(f"\nModel saved to: {final_h5_path}")

# ============================================================
# 12. CONVERT TO TFLITE
# ============================================================
print("\nConverting to TFLite...")

# Rebuild a clean float32 model without augmentation layers (TFLite incompatible)
mixed_precision.set_global_policy('float32')

export_base = EfficientNetB0(
    include_top=False, weights=None, input_shape=(IMG_SIZE, IMG_SIZE, 3),
)
export_inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = export_base(export_inputs, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.4)(x)
x = layers.Dense(256, activation="relu")(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.3)(x)
export_outputs = layers.Dense(NUM_CLASSES, activation="softmax")(x)

export_model = keras.Model(export_inputs, export_outputs)

# Transfer weights: skip input in both, skip augmentation in trained model
for el, tl in zip(export_model.layers[1:], model.layers[2:]):
    ws = tl.get_weights()
    if ws:
        el.set_weights([w.astype('float32') if hasattr(w, 'astype') else w for w in ws])

# Sanity check
for images, labels in val_ds.take(1):
    orig_pred = np.argmax(model.predict(images[0:1], verbose=0))
    export_pred = np.argmax(export_model.predict(images[0:1], verbose=0))
    print(f"Sanity check — Original: {class_names[orig_pred]}, Export: {class_names[export_pred]}, Match: {orig_pred == export_pred}")

# Export as SavedModel then convert (avoids mixed-precision hanging)
saved_model_dir = os.path.join(SAVE_DIR, "saved_model_export")
export_model.export(saved_model_dir)

converter = tf.lite.TFLiteConverter.from_saved_model(saved_model_dir)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_types = [tf.float32]

tflite_model = converter.convert()
tflite_path = os.path.join(SAVE_DIR, "rice_pest_model.tflite")
with open(tflite_path, "wb") as f:
    f.write(tflite_model)

print(f"TFLite saved: {tflite_path} ({os.path.getsize(tflite_path) / (1024*1024):.2f} MB)")

# Save class names for inference
labels_path = os.path.join(SAVE_DIR, "class_labels.txt")
with open(labels_path, "w") as f:
    f.write("\n".join(class_names))
print(f"Class labels saved to: {labels_path}")

# ============================================================
# 13. VERIFY TFLITE MODEL
# ============================================================
interpreter = tf.lite.Interpreter(model_path=tflite_path)
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

print(f"\nTFLite input shape:  {input_details[0]['shape']}")
print(f"TFLite output shape: {output_details[0]['shape']}")
print(f"TFLite input dtype:  {input_details[0]['dtype']}")

# Quick inference test
for images, labels in val_ds.take(1):
    sample = tf.cast(images[0:1], input_details[0]['dtype']).numpy()
    interpreter.resize_tensor_input(input_details[0]['index'], sample.shape)
    interpreter.allocate_tensors()
    interpreter.set_tensor(input_details[0]['index'], sample)
    interpreter.invoke()
    output = interpreter.get_tensor(output_details[0]['index'])
    pred_class = class_names[np.argmax(output)]
    true_class = class_names[np.argmax(labels[0].numpy())]
    print(f"\nTFLite test — True: {true_class}, Predicted: {pred_class}")

print("\n" + "=" * 60)
print("DONE. All artifacts saved in:", SAVE_DIR)
print("=" * 60)
# Out:
# Mixed precision policy: mixed_float16
# Using Colab cache for faster access to the 'rice-pest-detection' dataset.
# Dataset downloaded to: /kaggle/input/rice-pest-detection
# Using data directory: /kaggle/input/rice-pest-detection/preprocessedDataset
# Classes found (12): ['Rice Leaf Roller', 'Rice Leaf Caterpillar', 'Rice Shell Pest', 'Thrips', 'Paddy Stem Maggot', 'Asiatic Rice Borer', 'Yellow Rice Borer', 'Rice Gall Midge', 'Brown Plant Hopper', 'Rice Stem Fly', 'Rice Water Weevil', 'Rice Leaf Hopper']
#   0 (Rice Leaf Roller): 605 images
#   1 (Rice Leaf Caterpillar): 475 images
#   10 (Rice Shell Pest): 480 images
#   11 (Thrips): 580 images
#   2 (Paddy Stem Maggot): 325 images
#   3 (Asiatic Rice Borer): 745 images
#   4 (Yellow Rice Borer): 455 images
#   5 (Rice Gall Midge): 791 images
#   6 (Brown Plant Hopper): 290 images
#   7 (Rice Stem Fly): 1110 images
#   8 (Rice Water Weevil): 1194 images
#   9 (Rice Leaf Hopper): 686 images
# Found 7736 files belonging to 12 classes.
# Using 6189 files for training.
# Found 7736 files belonging to 12 classes.
# Using 1547 files for validation.
#
# Num classes: 12
#
# Train label distribution: {np.int64(0): 504, np.int64(1): 376, np.int64(2): 403, np.int64(3): 456, np.int64(4): 267, np.int64(5): 577, np.int64(6): 351, np.int64(7): 646, np.int64(8): 231, np.int64(9): 872, np.int64(10): 953, np.int64(11): 553}
# Class weights: {0: np.float64(1.023313492063492), 1: np.float64(1.3716755319148937), 2: np.float64(1.2797766749379653), 3: np.float64(1.131030701754386), 4: np.float64(1.9316479400749065), 5: np.float64(0.8938474870017331), 6: np.float64(1.4693732193732194), 7: np.float64(0.798374613003096), 8: np.float64(2.232683982683983), 9: np.float64(0.5914564220183486), 10: np.float64(0.5411857292759706), 11: np.float64(0.9326401446654611)}
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_10 (InputLayer)     │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ data_augmentation (Sequential)  │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_4      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 1280)           │         5,120 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 12)             │         3,084 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,386,735 (16.73 MB)
#  Trainable params: 334,092 (1.27 MB)
#  Non-trainable params: 4,052,643 (15.46 MB)
# ============================================================
# PHASE 1: Training head layers (base frozen)
# ============================================================
# Epoch 1/20
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.5157 - loss: 1.6090
# Epoch 1: val_accuracy improved from -inf to 0.85197, saving model to saved_models/best_model_phase1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 44s 142ms/step - accuracy: 0.5170 - loss: 1.6041 - val_accuracy: 0.8520 - val_loss: 0.4890 - learning_rate: 0.0010
# Epoch 2/20
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7937 - loss: 0.6501
# Epoch 2: val_accuracy improved from 0.85197 to 0.89205, saving model to saved_models/best_model_phase1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 22s 113ms/step - accuracy: 0.7938 - loss: 0.6498 - val_accuracy: 0.8920 - val_loss: 0.3333 - learning_rate: 0.0010
# Epoch 3/20
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8285 - loss: 0.5318
# Epoch 3: val_accuracy improved from 0.89205 to 0.89722, saving model to saved_models/best_model_phase1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 21s 106ms/step - accuracy: 0.8285 - loss: 0.5316 - val_accuracy: 0.8972 - val_loss: 0.2826 - learning_rate: 0.0010
# Epoch 4/20
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8461 - loss: 0.4437
# Epoch 4: val_accuracy improved from 0.89722 to 0.91532, saving model to saved_models/best_model_phase1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 23s 117ms/step - accuracy: 0.8461 - loss: 0.4437 - val_accuracy: 0.9153 - val_loss: 0.2488 - learning_rate: 0.0010
# Epoch 5/20
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8655 - loss: 0.3831
# Epoch 5: val_accuracy improved from 0.91532 to 0.92566, saving model to saved_models/best_model_phase1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 22s 111ms/step - accuracy: 0.8656 - loss: 0.3832 - val_accuracy: 0.9257 - val_loss: 0.2194 - learning_rate: 0.0010
# Epoch 6/20
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8610 - loss: 0.4092
# Epoch 6: val_accuracy did not improve from 0.92566
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 21s 109ms/step - accuracy: 0.8610 - loss: 0.4090 - val_accuracy: 0.9257 - val_loss: 0.2101 - learning_rate: 0.0010
# Epoch 7/20
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8760 - loss: 0.3666
# Epoch 7: val_accuracy improved from 0.92566 to 0.93213, saving model to saved_models/best_model_phase1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 20s 105ms/step - accuracy: 0.8761 - loss: 0.3662 - val_accuracy: 0.9321 - val_loss: 0.1853 - learning_rate: 0.0010
# Epoch 8/20
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8869 - loss: 0.3266
# Epoch 8: val_accuracy improved from 0.93213 to 0.95023, saving model to saved_models/best_model_phase1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 21s 108ms/step - accuracy: 0.8869 - loss: 0.3266 - val_accuracy: 0.9502 - val_loss: 0.1746 - learning_rate: 0.0010
# Epoch 9/20
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8931 - loss: 0.3156
# Epoch 9: val_accuracy did not improve from 0.95023
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 21s 106ms/step - accuracy: 0.8931 - loss: 0.3156 - val_accuracy: 0.9489 - val_loss: 0.1495 - learning_rate: 0.0010
# Epoch 10/20
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8979 - loss: 0.2893
# Epoch 10: val_accuracy did not improve from 0.95023
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 22s 111ms/step - accuracy: 0.8980 - loss: 0.2892 - val_accuracy: 0.9463 - val_loss: 0.1516 - learning_rate: 0.0010
# Epoch 11/20
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9033 - loss: 0.2868
# Epoch 11: val_accuracy did not improve from 0.95023
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 21s 106ms/step - accuracy: 0.9033 - loss: 0.2868 - val_accuracy: 0.9412 - val_loss: 0.1582 - learning_rate: 0.0010
# Epoch 12/20
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9049 - loss: 0.2818
# Epoch 12: val_accuracy did not improve from 0.95023
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 40s 103ms/step - accuracy: 0.9049 - loss: 0.2818 - val_accuracy: 0.9399 - val_loss: 0.1442 - learning_rate: 0.0010
# Epoch 13/20
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9132 - loss: 0.2630
# Epoch 13: val_accuracy improved from 0.95023 to 0.95087, saving model to saved_models/best_model_phase1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 23s 118ms/step - accuracy: 0.9132 - loss: 0.2630 - val_accuracy: 0.9509 - val_loss: 0.1313 - learning_rate: 0.0010
# Epoch 14/20
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9042 - loss: 0.2737
# Epoch 14: val_accuracy did not improve from 0.95087
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 21s 107ms/step - accuracy: 0.9042 - loss: 0.2737 - val_accuracy: 0.9496 - val_loss: 0.1289 - learning_rate: 0.0010
# Epoch 15/20
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9074 - loss: 0.2559
# Epoch 15: val_accuracy did not improve from 0.95087
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 20s 105ms/step - accuracy: 0.9074 - loss: 0.2558 - val_accuracy: 0.9489 - val_loss: 0.1258 - learning_rate: 0.0010
# Epoch 16/20
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9083 - loss: 0.2840
# Epoch 16: val_accuracy improved from 0.95087 to 0.95798, saving model to saved_models/best_model_phase1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 21s 107ms/step - accuracy: 0.9084 - loss: 0.2837 - val_accuracy: 0.9580 - val_loss: 0.1194 - learning_rate: 0.0010
# Epoch 17/20
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9131 - loss: 0.2304
# Epoch 17: val_accuracy improved from 0.95798 to 0.95992, saving model to saved_models/best_model_phase1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 21s 109ms/step - accuracy: 0.9132 - loss: 0.2303 - val_accuracy: 0.9599 - val_loss: 0.1113 - learning_rate: 0.0010
# Epoch 18/20
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9208 - loss: 0.2362
# Epoch 18: val_accuracy did not improve from 0.95992
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 20s 105ms/step - accuracy: 0.9208 - loss: 0.2362 - val_accuracy: 0.9412 - val_loss: 0.1310 - learning_rate: 0.0010
# Epoch 19/20
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9244 - loss: 0.2238
# Epoch 19: val_accuracy improved from 0.95992 to 0.96122, saving model to saved_models/best_model_phase1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.9244 - loss: 0.2237 - val_accuracy: 0.9612 - val_loss: 0.1043 - learning_rate: 0.0010
# Epoch 20/20
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9220 - loss: 0.2253
# Epoch 20: val_accuracy did not improve from 0.96122
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 21s 108ms/step - accuracy: 0.9221 - loss: 0.2253 - val_accuracy: 0.9567 - val_loss: 0.1097 - learning_rate: 0.0010
#
# Trainable params after unfreezing: 1,830,252 / 4,386,735
#
# ============================================================
# PHASE 2: Fine-tuning top layers of EfficientNetB0
# ============================================================
# Epoch 1/30
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8229 - loss: 0.4916
# Epoch 1: val_accuracy improved from -inf to 0.94958, saving model to saved_models/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 46s 146ms/step - accuracy: 0.8231 - loss: 0.4910 - val_accuracy: 0.9496 - val_loss: 0.1302 - learning_rate: 1.0000e-04
# Epoch 2/30
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9014 - loss: 0.2962
# Epoch 2: val_accuracy improved from 0.94958 to 0.96122, saving model to saved_models/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 24s 121ms/step - accuracy: 0.9014 - loss: 0.2960 - val_accuracy: 0.9612 - val_loss: 0.1112 - learning_rate: 1.0000e-04
# Epoch 3/30
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9190 - loss: 0.2387
# Epoch 3: val_accuracy did not improve from 0.96122
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - accuracy: 0.9190 - loss: 0.2388 - val_accuracy: 0.9599 - val_loss: 0.0975 - learning_rate: 1.0000e-04
# Epoch 4/30
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9279 - loss: 0.2121
# Epoch 4: val_accuracy improved from 0.96122 to 0.96574, saving model to saved_models/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 23s 120ms/step - accuracy: 0.9279 - loss: 0.2119 - val_accuracy: 0.9657 - val_loss: 0.0928 - learning_rate: 1.0000e-04
# Epoch 5/30
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9411 - loss: 0.1619
# Epoch 5: val_accuracy improved from 0.96574 to 0.96639, saving model to saved_models/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 25s 129ms/step - accuracy: 0.9411 - loss: 0.1619 - val_accuracy: 0.9664 - val_loss: 0.0873 - learning_rate: 1.0000e-04
# Epoch 6/30
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9397 - loss: 0.1814
# Epoch 6: val_accuracy improved from 0.96639 to 0.96897, saving model to saved_models/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 40s 122ms/step - accuracy: 0.9398 - loss: 0.1812 - val_accuracy: 0.9690 - val_loss: 0.0836 - learning_rate: 1.0000e-04
# Epoch 7/30
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9516 - loss: 0.1507
# Epoch 7: val_accuracy improved from 0.96897 to 0.97027, saving model to saved_models/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 24s 122ms/step - accuracy: 0.9516 - loss: 0.1507 - val_accuracy: 0.9703 - val_loss: 0.0760 - learning_rate: 1.0000e-04
# Epoch 8/30
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9553 - loss: 0.1427
# Epoch 8: val_accuracy did not improve from 0.97027
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.9552 - loss: 0.1426 - val_accuracy: 0.9703 - val_loss: 0.0690 - learning_rate: 1.0000e-04
# Epoch 9/30
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9517 - loss: 0.1449
# Epoch 9: val_accuracy did not improve from 0.97027
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 41s 119ms/step - accuracy: 0.9517 - loss: 0.1449 - val_accuracy: 0.9677 - val_loss: 0.0802 - learning_rate: 1.0000e-04
# Epoch 10/30
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9550 - loss: 0.1139
# Epoch 10: val_accuracy did not improve from 0.97027
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 42s 124ms/step - accuracy: 0.9550 - loss: 0.1139 - val_accuracy: 0.9677 - val_loss: 0.0733 - learning_rate: 1.0000e-04
# Epoch 11/30
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9579 - loss: 0.1204
# Epoch 11: val_accuracy improved from 0.97027 to 0.97479, saving model to saved_models/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 41s 122ms/step - accuracy: 0.9579 - loss: 0.1204 - val_accuracy: 0.9748 - val_loss: 0.0618 - learning_rate: 1.0000e-04
# Epoch 12/30
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9555 - loss: 0.1198
# Epoch 12: val_accuracy did not improve from 0.97479
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - accuracy: 0.9555 - loss: 0.1198 - val_accuracy: 0.9741 - val_loss: 0.0564 - learning_rate: 1.0000e-04
# Epoch 13/30
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9640 - loss: 0.1174
# Epoch 13: val_accuracy did not improve from 0.97479
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 23s 117ms/step - accuracy: 0.9640 - loss: 0.1174 - val_accuracy: 0.9748 - val_loss: 0.0560 - learning_rate: 1.0000e-04
# Epoch 14/30
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9642 - loss: 0.1080
# Epoch 14: val_accuracy did not improve from 0.97479
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 41s 118ms/step - accuracy: 0.9642 - loss: 0.1080 - val_accuracy: 0.9748 - val_loss: 0.0575 - learning_rate: 1.0000e-04
# Epoch 15/30
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9653 - loss: 0.1122
# Epoch 15: val_accuracy improved from 0.97479 to 0.97673, saving model to saved_models/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 24s 122ms/step - accuracy: 0.9653 - loss: 0.1121 - val_accuracy: 0.9767 - val_loss: 0.0531 - learning_rate: 1.0000e-04
# Epoch 16/30
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9667 - loss: 0.0949
# Epoch 16: val_accuracy improved from 0.97673 to 0.97738, saving model to saved_models/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 24s 121ms/step - accuracy: 0.9667 - loss: 0.0949 - val_accuracy: 0.9774 - val_loss: 0.0565 - learning_rate: 1.0000e-04
# Epoch 17/30
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9675 - loss: 0.1051
# Epoch 17: val_accuracy improved from 0.97738 to 0.97802, saving model to saved_models/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 25s 130ms/step - accuracy: 0.9675 - loss: 0.1050 - val_accuracy: 0.9780 - val_loss: 0.0595 - learning_rate: 1.0000e-04
# Epoch 18/30
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9736 - loss: 0.0794
# Epoch 18: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 18: val_accuracy did not improve from 0.97802
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 25s 128ms/step - accuracy: 0.9736 - loss: 0.0794 - val_accuracy: 0.9774 - val_loss: 0.0532 - learning_rate: 1.0000e-04
# Epoch 19/30
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9696 - loss: 0.0923
# Epoch 19: val_accuracy did not improve from 0.97802
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 23s 118ms/step - accuracy: 0.9697 - loss: 0.0923 - val_accuracy: 0.9780 - val_loss: 0.0534 - learning_rate: 5.0000e-05
# Epoch 20/30
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9695 - loss: 0.0916
# Epoch 20: val_accuracy improved from 0.97802 to 0.98061, saving model to saved_models/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 41s 119ms/step - accuracy: 0.9695 - loss: 0.0915 - val_accuracy: 0.9806 - val_loss: 0.0487 - learning_rate: 5.0000e-05
# Epoch 21/30
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9716 - loss: 0.0844
# Epoch 21: val_accuracy did not improve from 0.98061
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 41s 118ms/step - accuracy: 0.9716 - loss: 0.0844 - val_accuracy: 0.9787 - val_loss: 0.0481 - learning_rate: 5.0000e-05
# Epoch 22/30
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9740 - loss: 0.0792
# Epoch 22: val_accuracy did not improve from 0.98061
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 24s 121ms/step - accuracy: 0.9740 - loss: 0.0793 - val_accuracy: 0.9806 - val_loss: 0.0478 - learning_rate: 5.0000e-05
# Epoch 23/30
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9773 - loss: 0.0767
# Epoch 23: val_accuracy did not improve from 0.98061
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 41s 122ms/step - accuracy: 0.9773 - loss: 0.0766 - val_accuracy: 0.9800 - val_loss: 0.0464 - learning_rate: 5.0000e-05
# Epoch 24/30
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9722 - loss: 0.0793
# Epoch 24: val_accuracy did not improve from 0.98061
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 23s 120ms/step - accuracy: 0.9722 - loss: 0.0793 - val_accuracy: 0.9800 - val_loss: 0.0466 - learning_rate: 5.0000e-05
# Epoch 25/30
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9767 - loss: 0.0682
# Epoch 25: val_accuracy did not improve from 0.98061
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 23s 118ms/step - accuracy: 0.9767 - loss: 0.0682 - val_accuracy: 0.9793 - val_loss: 0.0477 - learning_rate: 5.0000e-05
# Epoch 26/30
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9754 - loss: 0.0742
# Epoch 26: val_accuracy did not improve from 0.98061
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - accuracy: 0.9754 - loss: 0.0741 - val_accuracy: 0.9800 - val_loss: 0.0453 - learning_rate: 5.0000e-05
# Epoch 27/30
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9764 - loss: 0.0740
# Epoch 27: val_accuracy improved from 0.98061 to 0.98125, saving model to saved_models/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 42s 122ms/step - accuracy: 0.9764 - loss: 0.0740 - val_accuracy: 0.9813 - val_loss: 0.0434 - learning_rate: 5.0000e-05
# Epoch 28/30
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9763 - loss: 0.0700
# Epoch 28: val_accuracy improved from 0.98125 to 0.98255, saving model to saved_models/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 25s 129ms/step - accuracy: 0.9763 - loss: 0.0699 - val_accuracy: 0.9825 - val_loss: 0.0419 - learning_rate: 5.0000e-05
# Epoch 29/30
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9825 - loss: 0.0644
# Epoch 29: val_accuracy did not improve from 0.98255
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - accuracy: 0.9825 - loss: 0.0644 - val_accuracy: 0.9806 - val_loss: 0.0425 - learning_rate: 5.0000e-05
# Epoch 30/30
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9807 - loss: 0.0615
# Epoch 30: val_accuracy did not improve from 0.98255
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 25s 129ms/step - accuracy: 0.9806 - loss: 0.0615 - val_accuracy: 0.9813 - val_loss: 0.0440 - learning_rate: 5.0000e-05
#
# ============================================================
# EVALUATION
# ============================================================
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - accuracy: 0.9801 - loss: 0.0478
#
# Final Validation Loss: 0.0419
# Final Validation Accuracy: 0.9825
#
# --- Classification Report ---
#                        precision    recall  f1-score   support
#
#      Rice Leaf Roller     0.9612    0.9802    0.9706       101
# Rice Leaf Caterpillar     1.0000    1.0000    1.0000        99
#       Rice Shell Pest     0.9740    0.9740    0.9740        77
#                Thrips     1.0000    1.0000    1.0000       124
#     Paddy Stem Maggot     1.0000    1.0000    1.0000        58
#    Asiatic Rice Borer     0.9699    0.9583    0.9641       168
#     Yellow Rice Borer     0.9519    0.9519    0.9519       104
#       Rice Gall Midge     1.0000    1.0000    1.0000       145
#    Brown Plant Hopper     1.0000    1.0000    1.0000        59
#         Rice Stem Fly     0.9871    0.9664    0.9766       238
#     Rice Water Weevil     1.0000    1.0000    1.0000       241
#      Rice Leaf Hopper     0.9420    0.9774    0.9594       133
#
#              accuracy                         0.9825      1547
#             macro avg     0.9822    0.9840    0.9831      1547
#          weighted avg     0.9827    0.9825    0.9826      1547
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved to: saved_models/rice_pest_model_final.h5
#
# Converting to TFLite...
# Sanity check — Original: Rice Shell Pest, Export: Rice Shell Pest, Match: True
# Saved artifact at 'saved_models/saved_model_export'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_1491')
# Output Type:
#   TensorSpec(shape=(None, 12), dtype=tf.float32, name=None)
# Captures:
#   135941235065680: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   135941242240656: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   135941235064912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242240464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242239888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941235065872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941235065488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242240272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242239120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242239504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242238736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242238160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242238928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242237776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242240848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242238352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242237968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242239312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242237200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242238544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242236432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242239696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242237008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242236624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242236048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242235472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242236240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242236816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242235664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242235088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242234512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242235280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242234128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242237392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242234704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242234320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242235856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242233552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242234896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242232976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242240080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135946986346960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242232784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242233936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242237584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242233744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242233168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941242233360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135946986355024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135946986354640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941284838288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941284825808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941284837904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941284837520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941284838864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941284837712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941284837136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941284839056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941284839248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941284838480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941284836176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871029968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941284838672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941284838096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871029008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871028816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871029776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871030544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871031120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871030352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871031504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871029584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871030928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871031312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871030160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871032080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871030736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871032848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871029392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871032272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871032656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871033232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871033808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871033040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871032464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871033616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871034192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871034768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871034000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871035152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871031888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871034576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871034960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871033424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871035728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871034384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871036496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871036688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871036112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871035344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871037072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871037648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871036304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871038416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871037456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871038032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941235065104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871037840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871038992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871035536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871037264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871038800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871038608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871039568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871038224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871040336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871036880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871039760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871040144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871040720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871041296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871040528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871039952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871041104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871041680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871042256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871041488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871042640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871039376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871042064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871042448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871040912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871043216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871041872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871043984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871044176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871042832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871043792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871044368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871039184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871044752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871043600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871044560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871043024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871044944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940871043408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870358800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870358416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870357648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870357264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870357456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870358992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870357072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870359760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870359952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870359376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870358608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870360336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870360912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870359568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870359184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870360720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870361296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870361872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870361104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870362256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870360144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870361680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870362064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870360528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870362832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870361488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870363600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870357840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870363024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870363408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870363984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870364560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870363792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870363216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870364368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870364944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870365520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870364752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870365904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870362640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870365328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870365712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870364176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870366480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870365136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870367248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870367440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870366864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870366096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870367824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870368400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870367056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870366672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870368208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870368784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870369360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870368592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870369744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870367632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870369168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870369552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870368016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870370320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870368976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870371088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870371280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870370704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870369936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870371664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870372240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870370896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870370512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870372048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870372624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870373200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870372432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870372816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870371472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870371856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870373008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869276304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869275920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870370128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940870362448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869275728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869277264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869277072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869277648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869278224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869277456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869276112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869278032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869278608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869279184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869278416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869279568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869276688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869278992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869279376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869277840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869280144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869278800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869280912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869281104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869280528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869279760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869281488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869282064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869280720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869280336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869281872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869282448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869283024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869282256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869283408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869281296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869282832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869283216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869281680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869283984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869282640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869284752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869284944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869284368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869283600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869285328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869285904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869284560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869284176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869285712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869286288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869286864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869286096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869287248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869285136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869286672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869287056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869285520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869287824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869286480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869288592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869288784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869288208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869287440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869289168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869289744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869288400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869288016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869289552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869290128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869290704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869289936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869291088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869288976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869290896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869289360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869287632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869291664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869291472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869290512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869291280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869291856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940868178000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869290320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940869276880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940868178768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940868179728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135941235065296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940868179536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940868180112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940868179920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940868178576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940868181072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940868180880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940868180304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940868181456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135940868181264: TensorSpec(shape=(), dtype=tf.resource, name=None)
# TFLite saved: saved_models/rice_pest_model.tflite (16.55 MB)
# Class labels saved to: saved_models/class_labels.txt
#
# TFLite input shape:  [  1 224 224   3]
# TFLite output shape: [ 1 12]
# TFLite input dtype:  <class 'numpy.float32'>
#
# TFLite test — True: Paddy Stem Maggot, Predicted: Paddy Stem Maggot
#
# ============================================================
# DONE. All artifacts saved in: saved_models
# ============================================================
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
