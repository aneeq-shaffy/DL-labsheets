# %% [markdown]
# <a href="https://colab.research.google.com/github/aneeq-shaffy/DL-labsheets/blob/main/Disease_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Rice Disease Detection - Complete Training Pipeline
EfficientNetB0 Transfer Learning | Google Colab Ready
Dataset: Paddy Doctor (imbikramsaha/paddy-doctor)
"""

# ============================================================
# 1. IMPORTS & SETUP
# ============================================================
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks, mixed_precision
from tensorflow.keras.applications import EfficientNetB0
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns

# Enable mixed precision
policy = mixed_precision.Policy('mixed_float16')
mixed_precision.set_global_policy(policy)
print(f"Mixed precision policy: {policy.name}")

# Reproducibility
tf.random.set_seed(42)
np.random.seed(42)

# ============================================================
# 2. DATASET DOWNLOAD & PATH SETUP
# ============================================================
import kagglehub
dataset_path = kagglehub.dataset_download("imbikramsaha/paddy-doctor")
print(f"Dataset downloaded to: {dataset_path}")

# Walk the directory to find the folder containing class subdirectories
data_dir = dataset_path
for root, dirs, files in os.walk(dataset_path):
    if dirs and any(
        any(f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.webp'))
            for f in os.listdir(os.path.join(root, d)))
        for d in dirs if os.path.isdir(os.path.join(root, d))
    ):
        data_dir = root
        break

print(f"Using data directory: {data_dir}")

# Auto-discover class folders
folder_names = sorted([
    d for d in os.listdir(data_dir)
    if os.path.isdir(os.path.join(data_dir, d)) and not d.startswith('.')
])
class_names = folder_names
print(f"Classes found ({len(class_names)}): {class_names}")

for f in folder_names:
    count = len(os.listdir(os.path.join(data_dir, f)))
    print(f"  {f}: {count} images")

# ============================================================
# 3. DATA LOADING WITH TRAIN/VAL SPLIT
# ============================================================
IMG_SIZE = 224
BATCH_SIZE = 32

train_ds = keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=42,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode="categorical",
)

val_ds = keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=42,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode="categorical",
)

NUM_CLASSES = len(class_names)
print(f"\nNum classes: {NUM_CLASSES}")

# ============================================================
# 4. COMPUTE CLASS WEIGHTS
# ============================================================
all_labels = []
for _, labels in train_ds.unbatch():
    all_labels.append(np.argmax(labels.numpy()))
all_labels = np.array(all_labels)

label_counts = Counter(all_labels)
print(f"\nTrain label distribution: {dict(sorted(label_counts.items()))}")

class_weights_array = compute_class_weight(
    class_weight='balanced',
    classes=np.arange(NUM_CLASSES),
    y=all_labels,
)
class_weight_dict = {i: w for i, w in enumerate(class_weights_array)}
print(f"Class weights: {class_weight_dict}")

# ============================================================
# 5. DATA AUGMENTATION & PREFETCHING
# ============================================================
AUTOTUNE = tf.data.AUTOTUNE

data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.3),
    layers.RandomZoom((-0.2, 0.2)),
    layers.RandomContrast(0.2),
    layers.RandomTranslation(0.1, 0.1),
], name="data_augmentation")

train_ds = train_ds.prefetch(AUTOTUNE)
val_ds = val_ds.prefetch(AUTOTUNE)

# ============================================================
# 6. BUILD MODEL
# ============================================================
base_model = EfficientNetB0(
    include_top=False,
    weights="imagenet",
    input_shape=(IMG_SIZE, IMG_SIZE, 3),
)
base_model.trainable = False

inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = data_augmentation(inputs)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.4)(x)
x = layers.Dense(256, activation="relu")(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.3)(x)
# Float32 output for numerical stability with mixed precision
outputs = layers.Dense(NUM_CLASSES, activation="softmax", dtype="float32")(x)

model = keras.Model(inputs, outputs)
model.summary()

# ============================================================
# 7. PHASE 1 — TRAIN HEAD ONLY
# ============================================================
SAVE_DIR = "saved_models_disease"
os.makedirs(SAVE_DIR, exist_ok=True)

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

phase1_callbacks = [
    callbacks.EarlyStopping(
        monitor="val_accuracy", patience=5, restore_best_weights=True, mode="max"
    ),
    callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=3, min_lr=1e-6, verbose=1
    ),
    callbacks.ModelCheckpoint(
        os.path.join(SAVE_DIR, "best_model_phase1.h5"),
        monitor="val_accuracy", save_best_only=True, mode="max", verbose=1,
    ),
]

print("\n" + "=" * 60)
print("PHASE 1: Training head layers (base frozen)")
print("=" * 60)

history1 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=phase1_callbacks,
    class_weight=class_weight_dict,
)

# ============================================================
# 8. PHASE 2 — FINE-TUNE TOP LAYERS OF BASE
# ============================================================
base_model.trainable = True

# Freeze all layers except the last 30
for layer in base_model.layers[:-30]:
    layer.trainable = False

trainable_count = sum(1 for l in model.layers if l.trainable)
total_params = model.count_params()
trainable_params = sum(
    tf.reduce_prod(v.shape).numpy() for v in model.trainable_variables
)
print(f"\nTrainable params after unfreezing: {trainable_params:,} / {total_params:,}")

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

phase2_callbacks = [
    callbacks.EarlyStopping(
        monitor="val_accuracy", patience=7, restore_best_weights=True, mode="max"
    ),
    callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=3, min_lr=1e-7, verbose=1
    ),
    callbacks.ModelCheckpoint(
        os.path.join(SAVE_DIR, "best_model_final.h5"),
        monitor="val_accuracy", save_best_only=True, mode="max", verbose=1,
    ),
]

print("\n" + "=" * 60)
print("PHASE 2: Fine-tuning top layers of EfficientNetB0")
print("=" * 60)

history2 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=30,
    callbacks=phase2_callbacks,
    class_weight=class_weight_dict,
)

# ============================================================
# 9. EVALUATION
# ============================================================
print("\n" + "=" * 60)
print("EVALUATION")
print("=" * 60)

val_loss, val_acc = model.evaluate(val_ds)
print(f"\nFinal Validation Loss: {val_loss:.4f}")
print(f"Final Validation Accuracy: {val_acc:.4f}")

# Predictions
y_true, y_pred = [], []
for images, labels in val_ds:
    preds = model.predict(images, verbose=0)
    y_true.extend(np.argmax(labels.numpy(), axis=1))
    y_pred.extend(np.argmax(preds, axis=1))

y_true = np.array(y_true)
y_pred = np.array(y_pred)

# Classification report
print("\n--- Classification Report ---")
print(classification_report(y_true, y_pred, target_names=class_names, digits=4))

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(max(12, NUM_CLASSES), max(10, NUM_CLASSES * 0.8)))
sns.heatmap(
    cm, annot=True, fmt="d", cmap="Blues",
    xticklabels=class_names, yticklabels=class_names,
)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix — Rice Disease Detection")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig(os.path.join(SAVE_DIR, "confusion_matrix.png"), dpi=150)
plt.show()

# ============================================================
# 10. TRAINING HISTORY PLOTS
# ============================================================
def plot_history(h1, h2):
    acc = h1.history["accuracy"] + h2.history["accuracy"]
    val_acc = h1.history["val_accuracy"] + h2.history["val_accuracy"]
    loss = h1.history["loss"] + h2.history["loss"]
    val_loss = h1.history["val_loss"] + h2.history["val_loss"]
    epochs = range(1, len(acc) + 1)
    phase1_end = len(h1.history["accuracy"])

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

    ax1.plot(epochs, acc, label="Train Accuracy")
    ax1.plot(epochs, val_acc, label="Val Accuracy")
    ax1.axvline(x=phase1_end, color="gray", linestyle="--", label="Fine-tune start")
    ax1.set_title("Accuracy")
    ax1.set_xlabel("Epoch")
    ax1.legend()
    ax1.grid(True, alpha=0.3)

    ax2.plot(epochs, loss, label="Train Loss")
    ax2.plot(epochs, val_loss, label="Val Loss")
    ax2.axvline(x=phase1_end, color="gray", linestyle="--", label="Fine-tune start")
    ax2.set_title("Loss")
    ax2.set_xlabel("Epoch")
    ax2.legend()
    ax2.grid(True, alpha=0.3)

    plt.suptitle("Training History — Rice Disease Detection")
    plt.tight_layout()
    plt.savefig(os.path.join(SAVE_DIR, "training_history.png"), dpi=150)
    plt.show()

plot_history(history1, history2)

# ============================================================
# 11. SAVE FINAL MODEL
# ============================================================
final_h5_path = os.path.join(SAVE_DIR, "rice_disease_model_final.h5")
model.save(final_h5_path)
print(f"\nModel saved to: {final_h5_path}")

# Save class names for inference
labels_path = os.path.join(SAVE_DIR, "class_labels.txt")
with open(labels_path, "w") as f:
    f.write("\n".join(class_names))
print(f"Class labels saved to: {labels_path}")

# ============================================================
# 12. CONVERT TO TFLITE
# ============================================================
print("\nConverting to TFLite...")

# Rebuild a clean float32 model without augmentation layers
mixed_precision.set_global_policy('float32')

export_base = EfficientNetB0(
    include_top=False, weights=None, input_shape=(IMG_SIZE, IMG_SIZE, 3),
)
export_inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = export_base(export_inputs, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.4)(x)
x = layers.Dense(256, activation="relu")(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.3)(x)
export_outputs = layers.Dense(NUM_CLASSES, activation="softmax")(x)

export_model = keras.Model(export_inputs, export_outputs)

# Transfer weights: skip input in both, skip augmentation in trained model
for el, tl in zip(export_model.layers[1:], model.layers[2:]):
    ws = tl.get_weights()
    if ws:
        el.set_weights([w.astype('float32') if hasattr(w, 'astype') else w for w in ws])

# Sanity check
for images, labels in val_ds.take(1):
    orig_pred = np.argmax(model.predict(images[0:1], verbose=0))
    export_pred = np.argmax(export_model.predict(images[0:1], verbose=0))
    print(f"Sanity check — Original: {class_names[orig_pred]}, Export: {class_names[export_pred]}, Match: {orig_pred == export_pred}")

# Convert directly from Keras model to TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(export_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_types = [tf.float32]

tflite_model = converter.convert()
tflite_path = os.path.join(SAVE_DIR, "rice_disease_model.tflite")
with open(tflite_path, "wb") as f:
    f.write(tflite_model)

print(f"TFLite saved: {tflite_path} ({os.path.getsize(tflite_path) / (1024*1024):.2f} MB)")

# ============================================================
# 13. VERIFY TFLITE MODEL
# ============================================================
interpreter = tf.lite.Interpreter(model_path=tflite_path)
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

print(f"\nTFLite input shape:  {input_details[0]['shape']}")
print(f"TFLite output shape: {output_details[0]['shape']}")
print(f"TFLite input dtype:  {input_details[0]['dtype']}")

# Quick inference test
for images, labels in val_ds.take(1):
    sample = tf.cast(images[0:1], input_details[0]['dtype']).numpy()
    interpreter.resize_tensor_input(input_details[0]['index'], sample.shape)
    interpreter.allocate_tensors()
    interpreter.set_tensor(input_details[0]['index'], sample)
    interpreter.invoke()
    output = interpreter.get_tensor(output_details[0]['index'])
    pred_class = class_names[np.argmax(output)]
    true_class = class_names[np.argmax(labels[0].numpy())]
    print(f"\nTFLite test — True: {true_class}, Predicted: {pred_class}")

print("\n" + "=" * 60)
print("DONE. All artifacts saved in:", SAVE_DIR)
print("Files:")
print(f"  - {final_h5_path}")
print(f"  - {tflite_path}")
print(f"  - {labels_path}")
print("=" * 60)
# Out:
# Mixed precision policy: mixed_float16
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.13), please consider upgrading to the latest version (1.0.0).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/imbikramsaha/paddy-doctor?dataset_version_number=1...
# 100%|██████████| 1.02G/1.02G [00:47<00:00, 23.1MB/s]
# Extracting files...
# Dataset downloaded to: /root/.cache/kagglehub/datasets/imbikramsaha/paddy-doctor/versions/1
# Using data directory: /root/.cache/kagglehub/datasets/imbikramsaha/paddy-doctor/versions/1/paddy-disease-classification
# Classes found (2): ['test_images', 'train_images']
#   test_images: 3469 images
#   train_images: 10 images
# Found 13876 files belonging to 2 classes.
# Using 11101 files for training.
# Found 13876 files belonging to 2 classes.
# Using 2775 files for validation.
#
# Num classes: 2
#
# Train label distribution: {np.int64(0): 2792, np.int64(1): 8309}
# Class weights: {0: np.float64(1.9880014326647564), 1: np.float64(0.6680105909255024)}
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ data_augmentation (Sequential)  │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1280)           │         5,120 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │           514 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,384,165 (16.72 MB)
#  Trainable params: 331,522 (1.26 MB)
#  Non-trainable params: 4,052,643 (15.46 MB)
# ============================================================
# PHASE 1: Training head layers (base frozen)
# ============================================================
# Epoch 1/20
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.4905 - loss: 1.0781
# Epoch 1: val_accuracy improved from -inf to 0.61261, saving model to saved_models_disease/best_model_phase1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 110s 214ms/step - accuracy: 0.4905 - loss: 1.0777 - val_accuracy: 0.6126 - val_loss: 0.6637 - learning_rate: 0.0010
# Epoch 2/20
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.5043 - loss: 0.7330
# Epoch 2: val_accuracy improved from 0.61261 to 0.66955, saving model to saved_models_disease/best_model_phase1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 37s 107ms/step - accuracy: 0.5043 - loss: 0.7330 - val_accuracy: 0.6695 - val_loss: 0.6501 - learning_rate: 0.0010
# Epoch 3/20
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.4995 - loss: 0.7103
# Epoch 3: val_accuracy did not improve from 0.66955
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 40s 103ms/step - accuracy: 0.4995 - loss: 0.7103 - val_accuracy: 0.6061 - val_loss: 0.6630 - learning_rate: 0.0010
# Epoch 4/20
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.5119 - loss: 0.7078
# Epoch 4: val_accuracy did not improve from 0.66955
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 37s 106ms/step - accuracy: 0.5119 - loss: 0.7078 - val_accuracy: 0.4097 - val_loss: 0.7321 - learning_rate: 0.0010
# Epoch 5/20
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.5092 - loss: 0.7038
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 5: val_accuracy did not improve from 0.66955
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 41s 118ms/step - accuracy: 0.5092 - loss: 0.7039 - val_accuracy: 0.6382 - val_loss: 0.6676 - learning_rate: 0.0010
# Epoch 6/20
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.5149 - loss: 0.7001
# Epoch 6: val_accuracy did not improve from 0.66955
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 40s 116ms/step - accuracy: 0.5148 - loss: 0.7001 - val_accuracy: 0.6350 - val_loss: 0.6734 - learning_rate: 5.0000e-04
# Epoch 7/20
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.5084 - loss: 0.6982
# Epoch 7: val_accuracy did not improve from 0.66955
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 37s 107ms/step - accuracy: 0.5084 - loss: 0.6982 - val_accuracy: 0.6202 - val_loss: 0.6764 - learning_rate: 5.0000e-04
#
# Trainable params after unfreezing: 1,827,682 / 4,384,165
#
# ============================================================
# PHASE 2: Fine-tuning top layers of EfficientNetB0
# ============================================================
# Epoch 1/30
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.5005 - loss: 0.7033
# Epoch 1: val_accuracy improved from -inf to 0.51351, saving model to saved_models_disease/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 79s 153ms/step - accuracy: 0.5005 - loss: 0.7033 - val_accuracy: 0.5135 - val_loss: 0.6925 - learning_rate: 1.0000e-04
# Epoch 2/30
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.4881 - loss: 0.7050
# Epoch 2: val_accuracy improved from 0.51351 to 0.58631, saving model to saved_models_disease/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 64s 130ms/step - accuracy: 0.4881 - loss: 0.7050 - val_accuracy: 0.5863 - val_loss: 0.6811 - learning_rate: 1.0000e-04
# Epoch 3/30
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5047 - loss: 0.6967
# Epoch 3: val_accuracy did not improve from 0.58631
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 42s 122ms/step - accuracy: 0.5047 - loss: 0.6967 - val_accuracy: 0.4515 - val_loss: 0.7010 - learning_rate: 1.0000e-04
# Epoch 4/30
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.5049 - loss: 0.6963
# Epoch 4: val_accuracy did not improve from 0.58631
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 81s 118ms/step - accuracy: 0.5049 - loss: 0.6963 - val_accuracy: 0.4378 - val_loss: 0.7022 - learning_rate: 1.0000e-04
# Epoch 5/30
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.4982 - loss: 0.6953
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 5: val_accuracy did not improve from 0.58631
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 42s 122ms/step - accuracy: 0.4982 - loss: 0.6953 - val_accuracy: 0.5456 - val_loss: 0.6881 - learning_rate: 1.0000e-04
# Epoch 6/30
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5354 - loss: 0.6916
# Epoch 6: val_accuracy did not improve from 0.58631
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 85s 130ms/step - accuracy: 0.5354 - loss: 0.6916 - val_accuracy: 0.4652 - val_loss: 0.6962 - learning_rate: 5.0000e-05
# Epoch 7/30
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.5099 - loss: 0.6920
# Epoch 7: val_accuracy did not improve from 0.58631
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 41s 118ms/step - accuracy: 0.5099 - loss: 0.6920 - val_accuracy: 0.5784 - val_loss: 0.6842 - learning_rate: 5.0000e-05
# Epoch 8/30
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5260 - loss: 0.6899
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 8: val_accuracy improved from 0.58631 to 0.58991, saving model to saved_models_disease/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 42s 121ms/step - accuracy: 0.5260 - loss: 0.6899 - val_accuracy: 0.5899 - val_loss: 0.6821 - learning_rate: 5.0000e-05
# Epoch 9/30
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.5411 - loss: 0.6865
# Epoch 9: val_accuracy did not improve from 0.58991
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 42s 122ms/step - accuracy: 0.5411 - loss: 0.6865 - val_accuracy: 0.5892 - val_loss: 0.6811 - learning_rate: 2.5000e-05
# Epoch 10/30
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5163 - loss: 0.6928
# Epoch 10: val_accuracy did not improve from 0.58991
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 45s 129ms/step - accuracy: 0.5163 - loss: 0.6928 - val_accuracy: 0.5885 - val_loss: 0.6815 - learning_rate: 2.5000e-05
# Epoch 11/30
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5290 - loss: 0.6886
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 11: val_accuracy did not improve from 0.58991
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 41s 119ms/step - accuracy: 0.5290 - loss: 0.6886 - val_accuracy: 0.5074 - val_loss: 0.6928 - learning_rate: 2.5000e-05
# Epoch 12/30
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5232 - loss: 0.6887
# Epoch 12: val_accuracy did not improve from 0.58991
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 45s 131ms/step - accuracy: 0.5232 - loss: 0.6887 - val_accuracy: 0.4876 - val_loss: 0.6936 - learning_rate: 1.2500e-05
# Epoch 13/30
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.5274 - loss: 0.6880
# Epoch 13: val_accuracy did not improve from 0.58991
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 45s 130ms/step - accuracy: 0.5274 - loss: 0.6880 - val_accuracy: 0.4872 - val_loss: 0.6926 - learning_rate: 1.2500e-05
# Epoch 14/30
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.5259 - loss: 0.6897
# Epoch 14: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 14: val_accuracy did not improve from 0.58991
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 42s 121ms/step - accuracy: 0.5259 - loss: 0.6897 - val_accuracy: 0.4714 - val_loss: 0.6952 - learning_rate: 1.2500e-05
# Epoch 15/30
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5193 - loss: 0.6897
# Epoch 15: val_accuracy did not improve from 0.58991
# 347/347 ━━━━━━━━━━━━━━━━━━━━ 41s 118ms/step - accuracy: 0.5193 - loss: 0.6897 - val_accuracy: 0.4782 - val_loss: 0.6942 - learning_rate: 6.2500e-06
#
# ============================================================
# EVALUATION
# ============================================================
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.5957 - loss: 0.6811
#
# Final Validation Loss: 0.6821
# Final Validation Accuracy: 0.5899
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#  test_images     0.2481    0.3353    0.2852       677
# train_images     0.7581    0.6721    0.7125      2098
#
#     accuracy                         0.5899      2775
#    macro avg     0.5031    0.5037    0.4988      2775
# weighted avg     0.6336    0.5899    0.6082      2775
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved to: saved_models_disease/rice_disease_model_final.h5
# Class labels saved to: saved_models_disease/class_labels.txt
#
# Converting to TFLite...
# Sanity check — Original: train_images, Export: test_images, Match: False
# Saved artifact at '/tmp/tmp8ptdx6c4'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_494')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   136140939730896: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   136140939724368: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   136140939733776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939722832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939726096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939738384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939732240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939726864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939730512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939725328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939727440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939729168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939731472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939736080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939731088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939723984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939728784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939728976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939737040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939738192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939725136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939732432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939732048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939724944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939738576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939729936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939737808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077668560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077665296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077667024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077674704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077671632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077669904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077674512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077660304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077669712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077675856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077668368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077672784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077675088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077663568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077667408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077662032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077666064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077672016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077666832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077674128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077661072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077668176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077670480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077671440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077663952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077664336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077673552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077674896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077673744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077665104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077660496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077667216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077673360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077675280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077667984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077666256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077661456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077669328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077668944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077671248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077667600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077660688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077675664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077662608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077669520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077672208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077660880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077662224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077663184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077666448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077670288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077659920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077665680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077661648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077674320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077673936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077662992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077661840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077659728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077662416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077670672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077664528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077663376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077664720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077672400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077671056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077662800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077665872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077670864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077661264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077670096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077534800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077539984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077665488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939726288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077543248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077530576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077531344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077538064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077539216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077532688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077529808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077534032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077530384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077530960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077529040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077544784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077538256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077544208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077530192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077530000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077539600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077543056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077528848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077537488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077539408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077536528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077536912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077533840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077538832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077533264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077544016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077535568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077542288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077541136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077544592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077540368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077535760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077532304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077534992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077542864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077540752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077535376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077535952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077543632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077541904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077537680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077535184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077533648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077536336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077540560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077532880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077529232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077539024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077542480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077530768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077539792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077538448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077541712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077534608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077529424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077531536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077713680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077709456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077720976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077716368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077720208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077712720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077718480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077718672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077710800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077724624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077710608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077716176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077710992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077723280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077717328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077714832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077715024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077722896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077713104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077715408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077711568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077712336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077719632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077721360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077720016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077718096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077716560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077714448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077709648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077717904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077711952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077709072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077721552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077723088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077713488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077711760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077717712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077715600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077722128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077722512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077716944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077721168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077720400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077713296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077717520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077723856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077715216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077716752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077720592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077722320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077721936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077718864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077719248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077710224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077714064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077724432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077710416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077724048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077725008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077558672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077714640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077723664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077553872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077551184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077557136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077552720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077552528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077560016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077555792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077557520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077552912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077547536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077560208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077555984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077559824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077559632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077545616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077555216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077545808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077555024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077545040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077549456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077546768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077552336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077559248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077551952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077548304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077546192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077556752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077551568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077561168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077553680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077558864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077547728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077549264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077548496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077557904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077554256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077553104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077550416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077560592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077549840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077555600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077546576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077557712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077547344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077559440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077560400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077551760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077558096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077548880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077545424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077554832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077556560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077547152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077549648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077553296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077549072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077550032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077547920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077554448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077550800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077546000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077546960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077560976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077556176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077553488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077554640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077550224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068508752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068505488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141077558480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068517008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068505104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068507408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068509136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068501648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068508368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068503760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068513360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068516048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068506256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068512208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939742672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939744784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068515664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068501264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939745744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939743440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939745552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939740560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939743824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939740752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939744016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939737616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939739792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939741904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939739216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939740944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939742288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939743056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939744208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939742864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939743248: TensorSpec(shape=(), dtype=tf.resource, name=None)
# TFLite saved: saved_models_disease/rice_disease_model.tflite (16.54 MB)
#
# TFLite input shape:  [  1 224 224   3]
# TFLite output shape: [1 2]
# TFLite input dtype:  <class 'numpy.float32'>
#
# TFLite test — True: train_images, Predicted: train_images
#
# ============================================================
# DONE. All artifacts saved in: saved_models_disease
# Files:
#   - saved_models_disease/rice_disease_model_final.h5
#   - saved_models_disease/rice_disease_model.tflite
#   - saved_models_disease/class_labels.txt
# ============================================================
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
