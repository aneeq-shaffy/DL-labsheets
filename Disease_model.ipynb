# %% [markdown]
# <a href="https://colab.research.google.com/github/aneeq-shaffy/DL-labsheets/blob/main/Disease_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Rice Disease Detection - Complete Training Pipeline
EfficientNetB0 Transfer Learning | TFLite Export | Google Colab Ready
Dataset: Paddy Doctor (imbikramsaha/paddy-doctor)
"""

# ============================================================
# 1. IMPORTS & SETUP
# ============================================================
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks, mixed_precision
from tensorflow.keras.applications import EfficientNetB0
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns

# Enable mixed precision
policy = mixed_precision.Policy('mixed_float16')
mixed_precision.set_global_policy(policy)
print(f"Mixed precision policy: {policy.name}")

# Reproducibility
tf.random.set_seed(42)
np.random.seed(42)

# ============================================================
# 2. DATASET DOWNLOAD & PATH SETUP (FIXED)
# ============================================================
import kagglehub
dataset_path = kagglehub.dataset_download("imbikramsaha/paddy-doctor")
print(f"Dataset downloaded to: {dataset_path}")

# The paddy-doctor dataset has:
#   paddy-doctor/
#     train_images/        <-- contains the actual class subfolders
#       bacterial_leaf_blight/
#       blast/
#       brown_spot/
#       ...
#     test_images/
#       ...
# We must use train_images/ as data_dir, NOT the parent folder.

data_dir = os.path.join(dataset_path, "train_images")
if not os.path.isdir(data_dir):
    # Fallback: search for a folder with 3+ class subfolders (not train/test splits)
    data_dir = None
    for root, dirs, files in os.walk(dataset_path):
        class_dirs = [
            d for d in dirs
            if d not in ('train_images', 'test_images', 'train', 'test')
            and not d.startswith('.')
        ]
        if len(class_dirs) >= 3:
            data_dir = root
            break
    if data_dir is None:
        raise RuntimeError(f"Could not find class folders in {dataset_path}")

print(f"Using data directory: {data_dir}")

# Auto-discover class folders
folder_names = sorted([
    d for d in os.listdir(data_dir)
    if os.path.isdir(os.path.join(data_dir, d)) and not d.startswith('.')
])
class_names = folder_names
print(f"Classes found ({len(class_names)}): {class_names}")

for f in folder_names:
    count = len(os.listdir(os.path.join(data_dir, f)))
    print(f"  {f}: {count} images")

# ============================================================
# 3. DATA LOADING WITH TRAIN/VAL SPLIT
# ============================================================
IMG_SIZE = 224
BATCH_SIZE = 32

train_ds = keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=42,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode="categorical",
)

val_ds = keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=42,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode="categorical",
)

NUM_CLASSES = len(class_names)
print(f"\nNum classes: {NUM_CLASSES}")

# ============================================================
# 4. COMPUTE CLASS WEIGHTS
# ============================================================
all_labels = []
for _, labels in train_ds.unbatch():
    all_labels.append(np.argmax(labels.numpy()))
all_labels = np.array(all_labels)

label_counts = Counter(all_labels)
print(f"\nTrain label distribution: {dict(sorted(label_counts.items()))}")

class_weights_array = compute_class_weight(
    class_weight='balanced',
    classes=np.arange(NUM_CLASSES),
    y=all_labels,
)
class_weight_dict = {i: w for i, w in enumerate(class_weights_array)}
print(f"Class weights: {class_weight_dict}")

# ============================================================
# 5. DATA AUGMENTATION & PREFETCHING
# ============================================================
AUTOTUNE = tf.data.AUTOTUNE

data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.3),
    layers.RandomZoom((-0.2, 0.2)),
    layers.RandomContrast(0.2),
    layers.RandomTranslation(0.1, 0.1),
], name="data_augmentation")

train_ds = train_ds.prefetch(AUTOTUNE)
val_ds = val_ds.prefetch(AUTOTUNE)

# ============================================================
# 6. BUILD MODEL
# ============================================================
base_model = EfficientNetB0(
    include_top=False,
    weights="imagenet",
    input_shape=(IMG_SIZE, IMG_SIZE, 3),
)
base_model.trainable = False

inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = data_augmentation(inputs)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.4)(x)
x = layers.Dense(256, activation="relu")(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.3)(x)
# Float32 output for numerical stability with mixed precision
outputs = layers.Dense(NUM_CLASSES, activation="softmax", dtype="float32")(x)

model = keras.Model(inputs, outputs)
model.summary()

# ============================================================
# 7. PHASE 1 — TRAIN HEAD ONLY
# ============================================================
SAVE_DIR = "saved_models_disease"
os.makedirs(SAVE_DIR, exist_ok=True)

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

phase1_callbacks = [
    callbacks.EarlyStopping(
        monitor="val_accuracy", patience=5, restore_best_weights=True, mode="max"
    ),
    callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=3, min_lr=1e-6, verbose=1
    ),
    callbacks.ModelCheckpoint(
        os.path.join(SAVE_DIR, "best_model_phase1.h5"),
        monitor="val_accuracy", save_best_only=True, mode="max", verbose=1,
    ),
]

print("\n" + "=" * 60)
print("PHASE 1: Training head layers (base frozen)")
print("=" * 60)

history1 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=phase1_callbacks,
    class_weight=class_weight_dict,
)

# ============================================================
# 8. PHASE 2 — FINE-TUNE TOP LAYERS OF BASE
# ============================================================
base_model.trainable = True

# Freeze all layers except the last 30
for layer in base_model.layers[:-30]:
    layer.trainable = False

trainable_count = sum(1 for l in model.layers if l.trainable)
total_params = model.count_params()
trainable_params = sum(
    tf.reduce_prod(v.shape).numpy() for v in model.trainable_variables
)
print(f"\nTrainable params after unfreezing: {trainable_params:,} / {total_params:,}")

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

phase2_callbacks = [
    callbacks.EarlyStopping(
        monitor="val_accuracy", patience=7, restore_best_weights=True, mode="max"
    ),
    callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=3, min_lr=1e-7, verbose=1
    ),
    callbacks.ModelCheckpoint(
        os.path.join(SAVE_DIR, "best_model_final.h5"),
        monitor="val_accuracy", save_best_only=True, mode="max", verbose=1,
    ),
]

print("\n" + "=" * 60)
print("PHASE 2: Fine-tuning top layers of EfficientNetB0")
print("=" * 60)

history2 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=30,
    callbacks=phase2_callbacks,
    class_weight=class_weight_dict,
)

# ============================================================
# 9. EVALUATION
# ============================================================
print("\n" + "=" * 60)
print("EVALUATION")
print("=" * 60)

val_loss, val_acc = model.evaluate(val_ds)
print(f"\nFinal Validation Loss: {val_loss:.4f}")
print(f"Final Validation Accuracy: {val_acc:.4f}")

# Predictions
y_true, y_pred = [], []
for images, labels in val_ds:
    preds = model.predict(images, verbose=0)
    y_true.extend(np.argmax(labels.numpy(), axis=1))
    y_pred.extend(np.argmax(preds, axis=1))

y_true = np.array(y_true)
y_pred = np.array(y_pred)

# Classification report
print("\n--- Classification Report ---")
print(classification_report(y_true, y_pred, target_names=class_names, digits=4))

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(max(12, NUM_CLASSES), max(10, NUM_CLASSES * 0.8)))
sns.heatmap(
    cm, annot=True, fmt="d", cmap="Blues",
    xticklabels=class_names, yticklabels=class_names,
)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix — Rice Disease Detection")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig(os.path.join(SAVE_DIR, "confusion_matrix.png"), dpi=150)
plt.show()

# ============================================================
# 10. TRAINING HISTORY PLOTS
# ============================================================
def plot_history(h1, h2):
    acc = h1.history["accuracy"] + h2.history["accuracy"]
    val_acc = h1.history["val_accuracy"] + h2.history["val_accuracy"]
    loss = h1.history["loss"] + h2.history["loss"]
    val_loss = h1.history["val_loss"] + h2.history["val_loss"]
    epochs = range(1, len(acc) + 1)
    phase1_end = len(h1.history["accuracy"])

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

    ax1.plot(epochs, acc, label="Train Accuracy")
    ax1.plot(epochs, val_acc, label="Val Accuracy")
    ax1.axvline(x=phase1_end, color="gray", linestyle="--", label="Fine-tune start")
    ax1.set_title("Accuracy")
    ax1.set_xlabel("Epoch")
    ax1.legend()
    ax1.grid(True, alpha=0.3)

    ax2.plot(epochs, loss, label="Train Loss")
    ax2.plot(epochs, val_loss, label="Val Loss")
    ax2.axvline(x=phase1_end, color="gray", linestyle="--", label="Fine-tune start")
    ax2.set_title("Loss")
    ax2.set_xlabel("Epoch")
    ax2.legend()
    ax2.grid(True, alpha=0.3)

    plt.suptitle("Training History — Rice Disease Detection")
    plt.tight_layout()
    plt.savefig(os.path.join(SAVE_DIR, "training_history.png"), dpi=150)
    plt.show()

plot_history(history1, history2)

# ============================================================
# 11. SAVE FINAL MODEL
# ============================================================
final_h5_path = os.path.join(SAVE_DIR, "rice_disease_model_final.h5")
model.save(final_h5_path)
print(f"\nModel saved to: {final_h5_path}")

# Save class names for inference
labels_path = os.path.join(SAVE_DIR, "class_labels.txt")
with open(labels_path, "w") as f:
    f.write("\n".join(class_names))
print(f"Class labels saved to: {labels_path}")

# ============================================================
# 12. CONVERT TO TFLITE
# ============================================================
print("\nConverting to TFLite...")

# Rebuild a clean float32 model without augmentation layers
mixed_precision.set_global_policy('float32')

export_base = EfficientNetB0(
    include_top=False, weights=None, input_shape=(IMG_SIZE, IMG_SIZE, 3),
)
export_inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = export_base(export_inputs, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.4)(x)
x = layers.Dense(256, activation="relu")(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.3)(x)
export_outputs = layers.Dense(NUM_CLASSES, activation="softmax")(x)

export_model = keras.Model(export_inputs, export_outputs)

# Transfer weights: skip input in both, skip augmentation in trained model
for el, tl in zip(export_model.layers[1:], model.layers[2:]):
    ws = tl.get_weights()
    if ws:
        el.set_weights([w.astype('float32') if hasattr(w, 'astype') else w for w in ws])

# Sanity check
for images, labels in val_ds.take(1):
    orig_pred = np.argmax(model.predict(images[0:1], verbose=0))
    export_pred = np.argmax(export_model.predict(images[0:1], verbose=0))
    print(f"Sanity check — Original: {class_names[orig_pred]}, Export: {class_names[export_pred]}, Match: {orig_pred == export_pred}")

# Convert directly from Keras model to TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(export_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_types = [tf.float32]

tflite_model = converter.convert()
tflite_path = os.path.join(SAVE_DIR, "rice_disease_model.tflite")
with open(tflite_path, "wb") as f:
    f.write(tflite_model)

print(f"TFLite saved: {tflite_path} ({os.path.getsize(tflite_path) / (1024*1024):.2f} MB)")

# ============================================================
# 13. VERIFY TFLITE MODEL
# ============================================================
interpreter = tf.lite.Interpreter(model_path=tflite_path)
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

print(f"\nTFLite input shape:  {input_details[0]['shape']}")
print(f"TFLite output shape: {output_details[0]['shape']}")
print(f"TFLite input dtype:  {input_details[0]['dtype']}")

# Quick inference test
for images, labels in val_ds.take(1):
    sample = tf.cast(images[0:1], input_details[0]['dtype']).numpy()
    interpreter.resize_tensor_input(input_details[0]['index'], sample.shape)
    interpreter.allocate_tensors()
    interpreter.set_tensor(input_details[0]['index'], sample)
    interpreter.invoke()
    output = interpreter.get_tensor(output_details[0]['index'])
    pred_class = class_names[np.argmax(output)]
    true_class = class_names[np.argmax(labels[0].numpy())]
    print(f"\nTFLite test — True: {true_class}, Predicted: {pred_class}")

print("\n" + "=" * 60)
print("DONE. All artifacts saved in:", SAVE_DIR)
print("Files:")
print(f"  - {final_h5_path}")
print(f"  - {tflite_path}")
print(f"  - {labels_path}")
print("=" * 60)
# Out:
# Mixed precision policy: mixed_float16
# Using Colab cache for faster access to the 'paddy-doctor' dataset.
# Dataset downloaded to: /kaggle/input/paddy-doctor
# Using data directory: /kaggle/input/paddy-doctor/paddy-disease-classification/train_images
# Classes found (10): ['bacterial_leaf_blight', 'bacterial_leaf_streak', 'bacterial_panicle_blight', 'blast', 'brown_spot', 'dead_heart', 'downy_mildew', 'hispa', 'normal', 'tungro']
#   bacterial_leaf_blight: 479 images
#   bacterial_leaf_streak: 380 images
#   bacterial_panicle_blight: 337 images
#   blast: 1738 images
#   brown_spot: 965 images
#   dead_heart: 1442 images
#   downy_mildew: 620 images
#   hispa: 1594 images
#   normal: 1764 images
#   tungro: 1088 images
# Found 10407 files belonging to 10 classes.
# Using 8326 files for training.
# Found 10407 files belonging to 10 classes.
# Using 2081 files for validation.
#
# Num classes: 10
#
# Train label distribution: {np.int64(0): 393, np.int64(1): 301, np.int64(2): 266, np.int64(3): 1402, np.int64(4): 769, np.int64(5): 1162, np.int64(6): 499, np.int64(7): 1251, np.int64(8): 1425, np.int64(9): 858}
# Class weights: {0: np.float64(2.1185750636132314), 1: np.float64(2.7661129568106313), 2: np.float64(3.1300751879699247), 3: np.float64(0.5938659058487874), 4: np.float64(1.082704811443433), 5: np.float64(0.7165232358003443), 6: np.float64(1.6685370741482966), 7: np.float64(0.6655475619504396), 8: np.float64(0.584280701754386), 9: np.float64(0.9703962703962704)}
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ data_augmentation (Sequential)  │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 1280)           │         5,120 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,386,221 (16.73 MB)
#  Trainable params: 333,578 (1.27 MB)
#  Non-trainable params: 4,052,643 (15.46 MB)
# ============================================================
# PHASE 1: Training head layers (base frozen)
# ============================================================
# Epoch 1/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.2683 - loss: 2.4204
# Epoch 1: val_accuracy improved from -inf to 0.40557, saving model to saved_models_disease/best_model_phase1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 59s 177ms/step - accuracy: 0.2686 - loss: 2.4191 - val_accuracy: 0.4056 - val_loss: 1.6009 - learning_rate: 0.0010
# Epoch 2/20
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.4326 - loss: 1.6846
# Epoch 2: val_accuracy improved from 0.40557 to 0.45363, saving model to saved_models_disease/best_model_phase1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 31s 118ms/step - accuracy: 0.4328 - loss: 1.6840 - val_accuracy: 0.4536 - val_loss: 1.6140 - learning_rate: 0.0010
# Epoch 3/20
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.4828 - loss: 1.4824
# Epoch 3: val_accuracy did not improve from 0.45363
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 29s 113ms/step - accuracy: 0.4828 - loss: 1.4822 - val_accuracy: 0.4512 - val_loss: 1.6035 - learning_rate: 0.0010
# Epoch 4/20
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.5087 - loss: 1.3891
# Epoch 4: val_accuracy improved from 0.45363 to 0.49880, saving model to saved_models_disease/best_model_phase1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 41s 114ms/step - accuracy: 0.5087 - loss: 1.3889 - val_accuracy: 0.4988 - val_loss: 1.4313 - learning_rate: 0.0010
# Epoch 5/20
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.5424 - loss: 1.2917
# Epoch 5: val_accuracy improved from 0.49880 to 0.51898, saving model to saved_models_disease/best_model_phase1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 31s 118ms/step - accuracy: 0.5424 - loss: 1.2917 - val_accuracy: 0.5190 - val_loss: 1.4132 - learning_rate: 0.0010
# Epoch 6/20
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.5469 - loss: 1.3138
# Epoch 6: val_accuracy did not improve from 0.51898
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 29s 112ms/step - accuracy: 0.5470 - loss: 1.3135 - val_accuracy: 0.5151 - val_loss: 1.3864 - learning_rate: 0.0010
# Epoch 7/20
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.5574 - loss: 1.2512
# Epoch 7: val_accuracy did not improve from 0.51898
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 30s 113ms/step - accuracy: 0.5574 - loss: 1.2512 - val_accuracy: 0.5132 - val_loss: 1.4007 - learning_rate: 0.0010
# Epoch 8/20
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.5649 - loss: 1.2264
# Epoch 8: val_accuracy improved from 0.51898 to 0.53292, saving model to saved_models_disease/best_model_phase1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 48s 140ms/step - accuracy: 0.5649 - loss: 1.2262 - val_accuracy: 0.5329 - val_loss: 1.3674 - learning_rate: 0.0010
# Epoch 9/20
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.5678 - loss: 1.1912
# Epoch 9: val_accuracy did not improve from 0.53292
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 37s 140ms/step - accuracy: 0.5679 - loss: 1.1910 - val_accuracy: 0.5223 - val_loss: 1.3855 - learning_rate: 0.0010
# Epoch 10/20
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.5871 - loss: 1.1582
# Epoch 10: val_accuracy did not improve from 0.53292
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 30s 117ms/step - accuracy: 0.5871 - loss: 1.1582 - val_accuracy: 0.5156 - val_loss: 1.4255 - learning_rate: 0.0010
# Epoch 11/20
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.5890 - loss: 1.1345
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 11: val_accuracy did not improve from 0.53292
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 29s 112ms/step - accuracy: 0.5890 - loss: 1.1347 - val_accuracy: 0.4930 - val_loss: 1.4590 - learning_rate: 0.0010
# Epoch 12/20
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.5968 - loss: 1.1207
# Epoch 12: val_accuracy did not improve from 0.53292
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 30s 113ms/step - accuracy: 0.5968 - loss: 1.1206 - val_accuracy: 0.5267 - val_loss: 1.3804 - learning_rate: 5.0000e-04
# Epoch 13/20
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.6034 - loss: 1.0895
# Epoch 13: val_accuracy improved from 0.53292 to 0.54301, saving model to saved_models_disease/best_model_phase1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 35s 133ms/step - accuracy: 0.6034 - loss: 1.0893 - val_accuracy: 0.5430 - val_loss: 1.3459 - learning_rate: 5.0000e-04
# Epoch 14/20
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.6186 - loss: 1.0849
# Epoch 14: val_accuracy improved from 0.54301 to 0.56848, saving model to saved_models_disease/best_model_phase1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 36s 114ms/step - accuracy: 0.6186 - loss: 1.0848 - val_accuracy: 0.5685 - val_loss: 1.2534 - learning_rate: 5.0000e-04
# Epoch 15/20
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.6264 - loss: 1.0542
# Epoch 15: val_accuracy did not improve from 0.56848
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 30s 114ms/step - accuracy: 0.6263 - loss: 1.0542 - val_accuracy: 0.5493 - val_loss: 1.2933 - learning_rate: 5.0000e-04
# Epoch 16/20
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6244 - loss: 1.0313
# Epoch 16: val_accuracy improved from 0.56848 to 0.57617, saving model to saved_models_disease/best_model_phase1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 30s 115ms/step - accuracy: 0.6244 - loss: 1.0312 - val_accuracy: 0.5762 - val_loss: 1.2467 - learning_rate: 5.0000e-04
# Epoch 17/20
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.6313 - loss: 1.0358
# Epoch 17: val_accuracy did not improve from 0.57617
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 32s 121ms/step - accuracy: 0.6312 - loss: 1.0358 - val_accuracy: 0.5531 - val_loss: 1.2960 - learning_rate: 5.0000e-04
# Epoch 18/20
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.6218 - loss: 1.0463
# Epoch 18: val_accuracy improved from 0.57617 to 0.58626, saving model to saved_models_disease/best_model_phase1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 31s 119ms/step - accuracy: 0.6218 - loss: 1.0461 - val_accuracy: 0.5863 - val_loss: 1.1944 - learning_rate: 5.0000e-04
# Epoch 19/20
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.6310 - loss: 1.0205
# Epoch 19: val_accuracy did not improve from 0.58626
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 30s 115ms/step - accuracy: 0.6310 - loss: 1.0205 - val_accuracy: 0.5483 - val_loss: 1.3135 - learning_rate: 5.0000e-04
# Epoch 20/20
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.6291 - loss: 1.0368
# Epoch 20: val_accuracy did not improve from 0.58626
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 31s 119ms/step - accuracy: 0.6292 - loss: 1.0365 - val_accuracy: 0.5800 - val_loss: 1.2109 - learning_rate: 5.0000e-04
#
# Trainable params after unfreezing: 1,829,738 / 4,386,221
#
# ============================================================
# PHASE 2: Fine-tuning top layers of EfficientNetB0
# ============================================================
# Epoch 1/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4666 - loss: 1.6016
# Epoch 1: val_accuracy improved from -inf to 0.64344, saving model to saved_models_disease/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 62s 175ms/step - accuracy: 0.4668 - loss: 1.6009 - val_accuracy: 0.6434 - val_loss: 1.0866 - learning_rate: 1.0000e-04
# Epoch 2/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.5934 - loss: 1.1099
# Epoch 2: val_accuracy improved from 0.64344 to 0.66458, saving model to saved_models_disease/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 32s 124ms/step - accuracy: 0.5935 - loss: 1.1095 - val_accuracy: 0.6646 - val_loss: 1.0127 - learning_rate: 1.0000e-04
# Epoch 3/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.6412 - loss: 0.9796
# Epoch 3: val_accuracy improved from 0.66458 to 0.68381, saving model to saved_models_disease/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 33s 128ms/step - accuracy: 0.6412 - loss: 0.9794 - val_accuracy: 0.6838 - val_loss: 0.9828 - learning_rate: 1.0000e-04
# Epoch 4/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.6692 - loss: 0.8953
# Epoch 4: val_accuracy improved from 0.68381 to 0.69630, saving model to saved_models_disease/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 38s 145ms/step - accuracy: 0.6693 - loss: 0.8951 - val_accuracy: 0.6963 - val_loss: 0.9337 - learning_rate: 1.0000e-04
# Epoch 5/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.6967 - loss: 0.8404
# Epoch 5: val_accuracy improved from 0.69630 to 0.71985, saving model to saved_models_disease/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 34s 130ms/step - accuracy: 0.6968 - loss: 0.8401 - val_accuracy: 0.7198 - val_loss: 0.8544 - learning_rate: 1.0000e-04
# Epoch 6/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.7132 - loss: 0.7867
# Epoch 6: val_accuracy improved from 0.71985 to 0.73234, saving model to saved_models_disease/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 38s 144ms/step - accuracy: 0.7132 - loss: 0.7866 - val_accuracy: 0.7323 - val_loss: 0.8248 - learning_rate: 1.0000e-04
# Epoch 7/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.7376 - loss: 0.7171
# Epoch 7: val_accuracy improved from 0.73234 to 0.74147, saving model to saved_models_disease/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 33s 125ms/step - accuracy: 0.7376 - loss: 0.7170 - val_accuracy: 0.7415 - val_loss: 0.7943 - learning_rate: 1.0000e-04
# Epoch 8/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.7487 - loss: 0.6823
# Epoch 8: val_accuracy improved from 0.74147 to 0.76021, saving model to saved_models_disease/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 38s 146ms/step - accuracy: 0.7487 - loss: 0.6822 - val_accuracy: 0.7602 - val_loss: 0.7476 - learning_rate: 1.0000e-04
# Epoch 9/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.7603 - loss: 0.6496
# Epoch 9: val_accuracy did not improve from 0.76021
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 33s 127ms/step - accuracy: 0.7603 - loss: 0.6495 - val_accuracy: 0.7482 - val_loss: 0.7513 - learning_rate: 1.0000e-04
# Epoch 10/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.7665 - loss: 0.6320
# Epoch 10: val_accuracy did not improve from 0.76021
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 37s 143ms/step - accuracy: 0.7666 - loss: 0.6320 - val_accuracy: 0.7593 - val_loss: 0.7130 - learning_rate: 1.0000e-04
# Epoch 11/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.7759 - loss: 0.6092
# Epoch 11: val_accuracy improved from 0.76021 to 0.76069, saving model to saved_models_disease/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 38s 144ms/step - accuracy: 0.7759 - loss: 0.6091 - val_accuracy: 0.7607 - val_loss: 0.7147 - learning_rate: 1.0000e-04
# Epoch 12/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.7915 - loss: 0.5642
# Epoch 12: val_accuracy did not improve from 0.76069
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 33s 126ms/step - accuracy: 0.7916 - loss: 0.5642 - val_accuracy: 0.7506 - val_loss: 0.7404 - learning_rate: 1.0000e-04
# Epoch 13/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8006 - loss: 0.5439
# Epoch 13: val_accuracy improved from 0.76069 to 0.76213, saving model to saved_models_disease/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 33s 125ms/step - accuracy: 0.8006 - loss: 0.5438 - val_accuracy: 0.7621 - val_loss: 0.6816 - learning_rate: 1.0000e-04
# Epoch 14/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8113 - loss: 0.5110
# Epoch 14: val_accuracy improved from 0.76213 to 0.77559, saving model to saved_models_disease/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 34s 130ms/step - accuracy: 0.8113 - loss: 0.5110 - val_accuracy: 0.7756 - val_loss: 0.6424 - learning_rate: 1.0000e-04
# Epoch 15/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8072 - loss: 0.5021
# Epoch 15: val_accuracy improved from 0.77559 to 0.79097, saving model to saved_models_disease/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 34s 130ms/step - accuracy: 0.8072 - loss: 0.5021 - val_accuracy: 0.7910 - val_loss: 0.6263 - learning_rate: 1.0000e-04
# Epoch 16/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8252 - loss: 0.4787
# Epoch 16: val_accuracy improved from 0.79097 to 0.80538, saving model to saved_models_disease/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 33s 127ms/step - accuracy: 0.8252 - loss: 0.4787 - val_accuracy: 0.8054 - val_loss: 0.5736 - learning_rate: 1.0000e-04
# Epoch 17/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8309 - loss: 0.4534
# Epoch 17: val_accuracy did not improve from 0.80538
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 45s 143ms/step - accuracy: 0.8310 - loss: 0.4534 - val_accuracy: 0.7852 - val_loss: 0.6202 - learning_rate: 1.0000e-04
# Epoch 18/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8403 - loss: 0.4271
# Epoch 18: val_accuracy did not improve from 0.80538
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 33s 126ms/step - accuracy: 0.8403 - loss: 0.4272 - val_accuracy: 0.8025 - val_loss: 0.5848 - learning_rate: 1.0000e-04
# Epoch 19/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8534 - loss: 0.4232
# Epoch 19: val_accuracy improved from 0.80538 to 0.80971, saving model to saved_models_disease/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 33s 127ms/step - accuracy: 0.8533 - loss: 0.4232 - val_accuracy: 0.8097 - val_loss: 0.5515 - learning_rate: 1.0000e-04
# Epoch 20/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8395 - loss: 0.4264
# Epoch 20: val_accuracy improved from 0.80971 to 0.81499, saving model to saved_models_disease/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 34s 130ms/step - accuracy: 0.8395 - loss: 0.4264 - val_accuracy: 0.8150 - val_loss: 0.5403 - learning_rate: 1.0000e-04
# Epoch 21/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8508 - loss: 0.4128
# Epoch 21: val_accuracy improved from 0.81499 to 0.82508, saving model to saved_models_disease/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 38s 144ms/step - accuracy: 0.8508 - loss: 0.4128 - val_accuracy: 0.8251 - val_loss: 0.5328 - learning_rate: 1.0000e-04
# Epoch 22/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8597 - loss: 0.3988
# Epoch 22: val_accuracy did not improve from 0.82508
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 33s 126ms/step - accuracy: 0.8597 - loss: 0.3987 - val_accuracy: 0.8140 - val_loss: 0.5309 - learning_rate: 1.0000e-04
# Epoch 23/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8584 - loss: 0.3786
# Epoch 23: val_accuracy improved from 0.82508 to 0.82845, saving model to saved_models_disease/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 42s 128ms/step - accuracy: 0.8584 - loss: 0.3786 - val_accuracy: 0.8284 - val_loss: 0.5020 - learning_rate: 1.0000e-04
# Epoch 24/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8661 - loss: 0.3701
# Epoch 24: val_accuracy improved from 0.82845 to 0.83085, saving model to saved_models_disease/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 38s 145ms/step - accuracy: 0.8660 - loss: 0.3701 - val_accuracy: 0.8309 - val_loss: 0.5010 - learning_rate: 1.0000e-04
# Epoch 25/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8600 - loss: 0.3648
# Epoch 25: val_accuracy improved from 0.83085 to 0.83373, saving model to saved_models_disease/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 34s 129ms/step - accuracy: 0.8600 - loss: 0.3648 - val_accuracy: 0.8337 - val_loss: 0.4994 - learning_rate: 1.0000e-04
# Epoch 26/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8682 - loss: 0.3493
# Epoch 26: val_accuracy improved from 0.83373 to 0.84479, saving model to saved_models_disease/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 33s 125ms/step - accuracy: 0.8682 - loss: 0.3493 - val_accuracy: 0.8448 - val_loss: 0.4689 - learning_rate: 1.0000e-04
# Epoch 27/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8795 - loss: 0.3293
# Epoch 27: val_accuracy did not improve from 0.84479
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 33s 127ms/step - accuracy: 0.8795 - loss: 0.3292 - val_accuracy: 0.8371 - val_loss: 0.4700 - learning_rate: 1.0000e-04
# Epoch 28/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8775 - loss: 0.3239
# Epoch 28: val_accuracy improved from 0.84479 to 0.85296, saving model to saved_models_disease/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 33s 124ms/step - accuracy: 0.8775 - loss: 0.3240 - val_accuracy: 0.8530 - val_loss: 0.4451 - learning_rate: 1.0000e-04
# Epoch 29/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.8754 - loss: 0.3206
# Epoch 29: val_accuracy did not improve from 0.85296
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 33s 125ms/step - accuracy: 0.8754 - loss: 0.3206 - val_accuracy: 0.8472 - val_loss: 0.4603 - learning_rate: 1.0000e-04
# Epoch 30/30
# 260/261 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8801 - loss: 0.3220
# Epoch 30: val_accuracy improved from 0.85296 to 0.85824, saving model to saved_models_disease/best_model_final.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 41s 125ms/step - accuracy: 0.8801 - loss: 0.3219 - val_accuracy: 0.8582 - val_loss: 0.4255 - learning_rate: 1.0000e-04
#
# ============================================================
# EVALUATION
# ============================================================
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 7s 99ms/step - accuracy: 0.8626 - loss: 0.4180
#
# Final Validation Loss: 0.4255
# Final Validation Accuracy: 0.8582
#
# --- Classification Report ---
#                           precision    recall  f1-score   support
#
#    bacterial_leaf_blight     0.7549    0.8953    0.8191        86
#    bacterial_leaf_streak     0.8409    0.9367    0.8862        79
# bacterial_panicle_blight     0.8554    1.0000    0.9221        71
#                    blast     0.9030    0.8036    0.8504       336
#               brown_spot     0.7600    0.8724    0.8124       196
#               dead_heart     0.9962    0.9393    0.9669       280
#             downy_mildew     0.6795    0.8760    0.7653       121
#                    hispa     0.9222    0.7259    0.8124       343
#                   normal     0.8414    0.9233    0.8805       339
#                   tungro     0.8649    0.8348    0.8496       230
#
#                 accuracy                         0.8582      2081
#                macro avg     0.8418    0.8807    0.8565      2081
#             weighted avg     0.8679    0.8582    0.8586      2081
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved to: saved_models_disease/rice_disease_model_final.h5
# Class labels saved to: saved_models_disease/class_labels.txt
#
# Converting to TFLite...
# Sanity check — Original: brown_spot, Export: brown_spot, Match: True
# Saved artifact at '/tmp/tmp32ld5c8j'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_997')
# Output Type:
#   TensorSpec(shape=(None, 10), dtype=tf.float32, name=None)
# Captures:
#   136141069130000: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   136141069135568: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   136141069137488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069137680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069130768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069124432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069127696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069132688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069138832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069139792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069132880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069127312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069138640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069139408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069138448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069135376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069127888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069128080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069138064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069134992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069137104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141087667792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141087666448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141087665104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141087665872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141087663760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141087666832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141087667024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141087669136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141087663568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141087668944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141087665488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141087667600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141087669520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141087664144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141087668752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141087668368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141087669712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141087664912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141087670096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141087663376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141087668176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141087666064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141087666256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141087665680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141087664336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141087669904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141087669328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141087662032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141087667216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141087665296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069032464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069030544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069026320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069037456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069040720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069035728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069029392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069028624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069029584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069038992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069033232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069032080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069025936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069037840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069036496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069038416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069134416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069029776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069028048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069038608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069039376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069026128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069028240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069033040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069029008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069036304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069031696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069038032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069032848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069040144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069032656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069031120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069026896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069028816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069037072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069035344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069027856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069041104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069033616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069032272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069034960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069036880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069030736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069027280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069041296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069037648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069026704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069041488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069039184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069039760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069031888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069027088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069037264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069025360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069034384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069034192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069028432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069031312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069038800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069040336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069035536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069030928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069040912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069029200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069035920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069027472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069031504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070429520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069034768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069029968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070433552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070423376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070433360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070425104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070418192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070418384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070422608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070418960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070420112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070434128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070423952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070420880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070424720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070433168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070421264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070428560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070432400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070428752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070432592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070432784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070419536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070419344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070421072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070422992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070422800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070427408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070429328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070431824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070429904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070433744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070432016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070418000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070427600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070428944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070427024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070420304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070423568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070420688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070425488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070427216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070430096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070422032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070426832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070419728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070425296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070431056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070432976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070419920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070425680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070430288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070418576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070424528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070426256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070418768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070421840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070420496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070424144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070431440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070431248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070426640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070428368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070428176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070423184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070424912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070429712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070427984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070424336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070431632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070429136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070426064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141070430672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068456528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068464016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068464976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068461136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068465936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068460368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068467856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068463248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068455760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068464592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068466128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068454992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068464784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068460560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068463632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068459792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068463056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068467280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068454224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068457296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068462288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068458256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068467664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068454032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068455376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068454608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068456720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068460176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068456144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068466704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068453072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068452112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068455568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068461328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068464400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068452496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068464208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068452688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068453456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068463440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068453264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068462480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068457680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068465744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068454800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068467472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068462672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068458832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068463824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068460944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068465552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068457104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068461712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068458448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068461904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068456912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068452304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068459216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068457872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068453648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068455952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068458640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068466512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068458064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068460752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068467088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068459600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068452880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068459408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068465168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068466320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068455184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068462096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068466896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068453840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141068457488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069100688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069097616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069091088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069106256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069091472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069098768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069096848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069100304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069095312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069094544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069096464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069098960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069094160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069101072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069099728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069093968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069104528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069091856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069096080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069097040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069105488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069104336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069092624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069105872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069097232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069096656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069105680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069093392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069091280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069094352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069095120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069091664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069103760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069102800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069096272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069093008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069092816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069101840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069093584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069092240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069092048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069099536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069102032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069104912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069106832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136140939754384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069098576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069095696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069107024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069103184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069101456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069099152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069101648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069102608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136141069095504: TensorSpec(shape=(), dtype=tf.resource, name=None)
# TFLite saved: saved_models_disease/rice_disease_model.tflite (16.55 MB)
#
# TFLite input shape:  [  1 224 224   3]
# TFLite output shape: [ 1 10]
# TFLite input dtype:  <class 'numpy.float32'>
#
# TFLite test — True: hispa, Predicted: normal
#
# ============================================================
# DONE. All artifacts saved in: saved_models_disease
# Files:
#   - saved_models_disease/rice_disease_model_final.h5
#   - saved_models_disease/rice_disease_model.tflite
#   - saved_models_disease/class_labels.txt
# ============================================================
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
